# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pickle
# %matplotlib inline

# %%
M = np.array([[  6.65711273e-02,   5.47559773e+00,  -1.89238360e+02],
       [ -5.39128636e+00,   1.01174157e-01,   1.79414588e+03],
       [  6.35660769e-05,   8.09843393e-05,   1.00000000e+00]])

# %%
fname = '/home/shankha/MuralPlot/left.jpeg'
img = cv2.imread(fname)
im_out = cv2.warpPerspective(img, M, (1000,1000))
gray = cv2.cvtColor(im_out, cv2.COLOR_BGR2GRAY)
gray = gray[200:,:500]

# %%
plt.imshow(gray, cmap='gray')

# %%
thr = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,105, 10)
blur = cv2.blur(thr,(5,5))
cv2.Transpose(blur, flip)
plt.imshow(flip, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-a1571905052e> in <module>()
#       1 thr = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,105, 10)
#       2 blur = cv2.blur(thr,(5,5))
# ----> 3 cv2.Transpose(blur, flip)
#       4 plt.imshow(flip, cmap='gray')
#
# AttributeError: module 'cv2.cv2' has no attribute 'Transpose'

# %%
from tracking import Tracker

# %%
T = Tracker(cv2.imread('svg/brain.png'))

# %%
T.transform(thr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-8d31050b0477> in <module>()
# ----> 1 T.transform(thr)
#
# /home/shankha/MuralPlot/tracking.py in transform(self, image)
#      70         src, dst = self.conv_to_pts(kp1, kp2, goodMatches)
#      71         affineTransform = self.getAffineTransform(src, dst)
# ---> 72         x = -affineTransform[0][2]
#      73         y = -affineTransform[1][2]
#      74         theta = np.arccos(affineTransform[0,0])
#
# TypeError: 'NoneType' object is not subscriptable
